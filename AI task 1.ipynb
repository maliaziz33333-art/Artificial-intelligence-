# %%
Superior University Gold Campus
TASK 1:
Program:
BS ARTIFICIAL INTELLIGENCE
Course Name:
Artificial Intelligence 
Submitted to:
Sir Rasik Ali
Submitted by:
M. Ali Aziz
(SU92-BSAIM-S25-021)

# %%
Mini projects
. Dynamic calculator ( solving : 1+2×3(4-5÷4)-(3÷5) )

# %%
import re

def format_expression(expr):
    expr = expr.replace("×", "*").replace("÷", "/")
    expr = re.sub(r'(\d)\(', r'\1*(', expr)
    expr = re.sub(r'\)(\d)', r')*\1', expr)
    return expr

def dynamic_calculator():
    while True:
        expression = input("Enter expression (or type 'exit'): ")
        
        if expression.lower() == "exit":
            break
        
        try:
            formatted = format_expression(expression)
            result = eval(formatted)
            print("Result:", result)
        except:
            print("Invalid expression")

dynamic_calculator()
# Out:
# Enter expression (or type 'exit'):  1+2×3(4-5÷4)-(3÷5)
# Result: 16.9
# Enter expression (or type 'exit'):  exit
